# %% [markdown]
# Clone with submodules

# %%
# !git clone --recursive https://github.com/khadas/aml_npu_sdk.git
# Out:
# Cloning into 'aml_npu_sdk'...
# remote: Enumerating objects: 697, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 697 (delta 0), reused 2 (delta 0), pack-reused 694
# Receiving objects: 100% (697/697), 51.89 MiB | 31.82 MiB/s, done.
# Resolving deltas: 100% (428/428), done.
# Submodule 'acuity-toolkit/bin' (https://gitlab.com/khadas/neural_network_large_file.git) registered for path 'acuity-toolkit/bin'
# Submodule 'acuity-toolkit/python' (https://gitlab.com/khadas/neural_network_large_file.git) registered for path 'acuity-toolkit/python'
# Cloning into '/content/aml_npu_sdk/acuity-toolkit/bin'...
# remote: Enumerating objects: 13584, done.
# remote: Counting objects: 100% (1892/1892), done.
# remote: Compressing objects: 100% (1766/1766), done.
# remote: Total 13584 (delta 155), reused 1241 (delta 101), pack-reused 11692
# Receiving objects: 100% (13584/13584), 3.97 GiB | 24.87 MiB/s, done.
# ...

# %% [markdown]
# update submodules

# %%
# !git submodule init
# !git submodule update
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# 開啟 Google 雲端硬碟

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# %ls
# Out:
# /
# Mounted at /content/gdrive
# bin@                        datalab/  lib@     media/                    proc/        sbin@  tools/
# boot/                       dev/      lib32@   mnt/                      python-apt/  srv/   usr/
# content/                    etc/      lib64@   NGC-DL-CONTAINER-LICENSE  root/        sys/   var/
# cuda-keyring_1.0-1_all.deb  home/     libx32@  opt/                      run/         tmp/

# %%
# %cd ..
# %ls
# Out:
# /
# bin@                        data_test/   lib@     mnt/                      python-apt/  sys/
# boot/                       dev/         lib32@   model_test/               root/        tmp/
# content/                    etc/         lib64@   NGC-DL-CONTAINER-LICENSE  run/         tools/
# cuda-keyring_1.0-1_all.deb  home/        libx32@  opt/                      sbin@        usr/
# datalab/                    JPEGImages/  media/   proc/                     srv/         var/

# %% [markdown]
# 進入目標目錄 建立對應資料夾

# %%
# %cd content/aml_npu_sdk/acuity-toolkit/demo
# !mkdir model_test
# !mkdir data_test
# !mkdir JPEGImages
# Out:
# /content/aml_npu_sdk/acuity-toolkit/demo

# %% [markdown]
# 複製上課資料

# %%
# !cp -r /content/gdrive/MyDrive/0131/VIPNANOQI_PID0XAD /content/aml_npu_sdk/acuity-toolkit/bin/
# !cp -r /content/gdrive/MyDrive/data/results/* /content/aml_npu_sdk/acuity-toolkit/demo/model_test/
#!cp -r /content/gdrive/MyDrive/0131/data_test/* /aml_npu_sdk/acuity-toolkit/demo/data_test/
# !cp -r /content/gdrive/MyDrive/data/JPEGImages/* /content/aml_npu_sdk/acuity-toolkit/demo/JPEGImages/
#!cp -r /content/gdrive/MyDrive/data/results/* /aml_npu_sdk/acuity-toolkit/demo/model_test/
# !cp -r /content/gdrive/MyDrive/data/train.txt /content/aml_npu_sdk/acuity-toolkit/demo/dataset_test.txt

# !cp -r /content/gdrive/MyDrive/0131/0_import_model_test.sh /content/aml_npu_sdk/acuity-toolkit/demo/
# !cp -r /content/gdrive/MyDrive/0131/1_quantize_model_test.sh /content/aml_npu_sdk/acuity-toolkit/demo/
# !cp -r /content/gdrive/MyDrive/0131/2_export_case_code_test.sh /content/aml_npu_sdk/acuity-toolkit/demo/

# %%
# This stops 'Run all' at this cell by causing an error
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-13-90e9831ca4f5> in <cell line: 2>()
#       1 # This stops 'Run all' at this cell by causing an error
# ----> 2 assert False
#
# AssertionError:

# %% [markdown]
# 需手動修改相關檔案 0_import_model.sh, 1_quantize_model.sh, 2_export_case_code.sh 並依序執行下面步驟
# 1.  導入模型
# 2.  量化模型
# 3.  生成 Binary

# %% [markdown]
# 1. 導入模型

# %%
#!bash ./0_import_model.sh

# %%
# %ls
# %cd content/aml_npu_sdk/acuity-toolkit/demo/
# Out:
# bin@                        data_test/   lib@     mnt/                      python-apt/  sys/
# boot/                       dev/         lib32@   model_test/               root/        tmp/
# content/                    etc/         lib64@   NGC-DL-CONTAINER-LICENSE  run/         tools/
# cuda-keyring_1.0-1_all.deb  home/        libx32@  opt/                      sbin@        usr/
# datalab/                    JPEGImages/  media/   proc/                     srv/         var/
# /content/aml_npu_sdk/acuity-toolkit/demo

# %%
# !bash ./0_import_model_test.sh
# Out:
# 2024-01-31 17:41:29.202023: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /content/aml_npu_sdk/acuity-toolkit/bin/acuitylib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-31 17:41:29.202097: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# I Namespace(import='darknet', model='./model_test/yolov4-tiny-test.cfg', output_data='yolov4_test.data', output_model='yolov4_test.json', weights='./model_test/yolov4-tiny-test_last.weights', which='import')
# I Start importing darknet...
# I Convert -1 net
# I Convert 0 convolutional
# I Convert 1 convolutional
# I Convert 2 convolutional
# I Convert 3 route
# I Convert 4 convolutional
# I Convert 5 convolutional
# I Convert 6 route
# I Convert 7 convolutional
# I Convert 8 route
# ...

# %% [markdown]
# 2. 量化模型

# %%
#!bash ./1_quantize_model.sh

# %%
# !bash ./1_quantize_model_test.sh
# Out:
# 2024-01-31 17:43:28.759053: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /content/aml_npu_sdk/acuity-toolkit/bin/acuitylib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-31 17:43:28.759103: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# I Namespace(MLE=False, algorithm='normal', batch_size=0, compute_entropy=False, device=None, divergence_first_quantize_bits=11, divergence_nbins=0, hybrid=False, iterations=1, model='yolov4_test.json', model_data='yolov4_test.data', model_quantize=None, moving_average_weight=0.01, output_dir=None, qtype='uint8', quantizer='asymmetric_affine', rebuild=True, rebuild_all=False, which='quantize', with_input_meta='yolov4_test_inputmeta.yml')
# ...

# %% [markdown]
# 3. 生成Binary

# %%
#!bash ./2_export_case_code.sh

# %%
# !bash ./2_export_case_code_test.sh
# Out:
# 2024-01-31 17:44:07.683308: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /content/aml_npu_sdk/acuity-toolkit/bin/acuitylib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-31 17:44:07.683364: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %%
# !cp -r /content/aml_npu_sdk/acuity-toolkit/demo/yolov4_test_nbg_viplite/yolov4_test.nb /content/gdrive/MyDrive/data/results/
