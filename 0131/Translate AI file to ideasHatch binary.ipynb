# %% [markdown]
# Clone with submodules

# %%
# !git clone --recursive https://github.com/khadas/aml_npu_sdk.git

# %% [markdown]
# update submodules

# %%
# !git submodule init
# !git submodule update

# %% [markdown]
# 開啟 Google 雲端硬碟

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# %ls

# %%
# %cd ..
# %ls

# %% [markdown]
# 進入目標目錄 建立對應資料夾

# %%
# %cd aml_npu_sdk/acuity-toolkit/demo
# !mkdir model_test
# !mkdir data_test
# !mkdir JPEGImages

# %% [markdown]
# 複製上課資料

# %%
# !cp -r /content/gdrive/MyDrive/0131/VIPNANOQI_PID0XAD /aml_npu_sdk/acuity-toolkit/bin/
#!cp -r /content/gdrive/MyDrive/0131/model_test/* /aml_npu_sdk/acuity-toolkit/demo/model_test/
#!cp -r /content/gdrive/MyDrive/0131/data_test/* /aml_npu_sdk/acuity-toolkit/demo/data_test/
# !cp -r /content/gdrive/MyDrive/data/JPEGImages/* /aml_npu_sdk/acuity-toolkit/demo/JPEGImages/
#!cp -r /content/gdrive/MyDrive/data/results/* /aml_npu_sdk/acuity-toolkit/demo/model_test/
# !cp -r /content/gdrive/MyDrive/data/train.txt /aml_npu_sdk/acuity-toolkit/demo/data_test.txt

# !cp -r /content/gdrive/MyDrive/0131/0_import_model_test.sh /aml_npu_sdk/acuity-toolkit/demo/
# !cp -r /content/gdrive/MyDrive/0131/1_quantize_model_test.sh /aml_npu_sdk/acuity-toolkit/demo/
# !cp -r /content/gdrive/MyDrive/0131/2_export_case_code_test.sh /aml_npu_sdk/acuity-toolkit/demo/

# %%
# This stops 'Run all' at this cell by causing an error
assert False

# %% [markdown]
# 需手動修改相關檔案 0_import_model.sh, 1_quantize_model.sh, 2_export_case_code.sh 並依序執行下面步驟
# 1.  導入模型
# 2.  量化模型
# 3.  生成 Binary

# %% [markdown]
# 1. 導入模型

# %%
#!bash ./0_import_model.sh

# %%
# !bash ./0_import_model_test.sh

# %% [markdown]
# 2. 量化模型

# %%
#!bash ./1_quantize_model.sh

# %%
# !bash ./1_quantize_model_test.sh

# %% [markdown]
# 3. 生成Binary

# %%
#!bash ./2_export_case_code.sh

# %%
# !bash ./2_export_case_code_test.sh
